# %% [markdown]
# # Airline Arrivals
#
# Use this [dataset of airline arrival information](http://stat-computing.org/dataexpo/2009/the-data.html) to predict how late flights will be.  A flight only counts as late if it is more than 30 mins late.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from datetime import datetime

# %matplotlib inline

# %%
file = 'C:/Users/Carter Carlson/Documents/Thinkful/Large Databases/2000.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2000      1          28          5   1647.0        1647   1906.0
# 1  2000      1          29          6   1648.0        1647   1939.0
# 2  2000      1          30          7      NaN        1647      NaN
# 3  2000      1          31          1   1645.0        1647   1852.0
# 4  2000      1           1          6    842.0         846   1057.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        1859            HP        154        ...             15       11
# 1        1859            HP        154        ...              5       47
# 2        1859            HP        154        ...              0        0
# 3        1859            HP        154        ...              7       14
# 4        1101            HP        609        ...              3        8
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.dropna(subset=['ArrTime', 'CRSArrTime'], inplace=True)
df['ArrTime'] = df['ArrTime'].astype(int)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2000      1          28          5   1647.0        1647     1906
# 1  2000      1          29          6   1648.0        1647     1939
# 3  2000      1          31          1   1645.0        1647     1852
# 4  2000      1           1          6    842.0         846     1057
# 5  2000      1           2          7    849.0         846     1148
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        1859            HP        154        ...             15       11
# 1        1859            HP        154        ...              5       47
# 3        1859            HP        154        ...              7       14
# 4        1101            HP        609        ...              3        8
# 5        1101            HP        609        ...              8       24
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df['ArrTime'] = pd.to_datetime(df['ArrTime'], format='%H%M')
df['CRSArrTime'] = pd.to_datetime(df['CRSArrTime'], format='%H%M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f299f1e6c732> in <module>()
# ----> 1 df['ArrTime'] = pd.to_datetime(df['ArrTime'], format='%H%M')
#       2 df['CRSArrTime'] = pd.to_datetime(df['CRSArrTime'], format='%H%M')
#
# ...

# %%
test = []
[test[x] = pd.to_datetime(df['ArrTime'][x], format='%H%M') for x in df['ArrTime']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-291963fbd9c2> in <module>()
#       1 test = []
# ----> 2 [test[x] == pd.to_datetime(df['ArrTime'][x], format='%H%M') for x in df['ArrTime']]
#
# <ipython-input-10-291963fbd9c2> in <listcomp>(.0)
#       1 test = []
# ----> 2 [test[x] == pd.to_datetime(df['ArrTime'][x], format='%H%M') for x in df['ArrTime']]
#
# IndexError: list index out of range

# %% [markdown]
# **Note: I want to:**
# 1. Convert ArrTime and CRSArrTime from Float to Int, then to Str
# 2. Convert ArrTime and CRSArrTime to datetime
# 3. create column 'Late' that is True/False if the difference of ArrTime and CRSArrTime > 30

# %%
pd.to_datetime(df['ArrTime'][1], format='%H%M')
# Out:
# Timestamp('1900-01-01 19:39:00')

# %%
df['ArrTime'][7]
# Out:
# 1912

# %%
x = [pd.to_datetime(x, format='%H%M') for x in df['ArrTime']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     302             try:
# --> 303                 values, tz = tslib.datetime_to_datetime64(arg)
#     304                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-84c6b8743dfc> in <module>()
# ----> 1 x = [pd.to_datetime(x, format='%H%M') for x in df['ArrTime']]
#
# <ipython-input-19-84c6b8743dfc> in <listcomp>(.0)
# ----> 1 x = [pd.to_datetime(x, format='%H%M') for x in df['ArrTime']]
#
# ...

# %%
FMT = '%H%M'
test = datetime.strftime(df['ArrTime'], FMT) - datetime.strftime(df['CRSArrTime'], FMT)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-735f6b703078> in <module>()
#       1 FMT = '%H%M'
# ----> 2 test = [datetime.strftime(df['ArrTime'], FMT) - datetime.strftime(df['CRSArrTime'], FMT) for x in df['ArrTime']]
#
# <ipython-input-116-735f6b703078> in <listcomp>(.0)
#       1 FMT = '%H%M'
# ----> 2 test = [datetime.strftime(df['ArrTime'], FMT) - datetime.strftime(df['CRSArrTime'], FMT) for x in df['ArrTime']]
#
# TypeError: descriptor 'strftime' requires a 'datetime.date' object but received a 'Series'
