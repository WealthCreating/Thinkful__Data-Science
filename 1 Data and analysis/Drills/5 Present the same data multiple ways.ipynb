# %% [markdown]
# ### 1. Choose one variable and plot that variable four different ways.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset("tips")

# %%
plt.plot(df['total_bill'])
plt.show()
plt.hist(df['total_bill'], bins=10)
plt.show()
norm = np.random.normal(0,1,df['total_bill'].count())
norm.sort()
plt.plot(norm, df['total_bill'].sort_values(), "o")
plt.show()
# Note: what is a 4th graph for single-variable?

# %% [markdown]
# ### 2. Choose two continuous variables, and plot them three different ways.

# %%
bill = df['total_bill']
tip = df['tip']
plt.scatter(x = bill, y = tip)
plt.show()
plt.hist(bill, color='red', alpha=.5, label='Total Bill', bins=10)
plt.hist(tip, color='blue', alpha=.5, label='Tip', bins=10)
plt.show()
g = sns.lmplot(y='tip',
               x='total_bill',
               data=df,
               fit_reg=True,
               scatter_kws={'alpha':0.4})
plt.show()

# %% [markdown]
# ### 3. Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
list(df)
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
graph = sns.boxplot(x='day', y='total_bill', data=df)
graph2 = sns.factorplot(x='day', y='total_bill', data=df, type='point', join=False, hue='day')
plt.show()
graph3 = sns.FacetGrid(df, col='day')
graph3.map(plt.hist, 'total_bill')
plt.show()
